# %% [markdown]
# here I will use keras model for transfer learning approach

# %%
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.applications.InceptionV3(include_top=True)
print(model.summary())
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 299, 299, 3)]        0         []
#
#  conv2d_1128 (Conv2D)        (None, 149, 149, 32)         864       ['input_13[0][0]']
#
#  batch_normalization_1128 (  (None, 149, 149, 32)         96        ['conv2d_1128[0][0]']
#  BatchNormalization)
#
#  activation_1128 (Activatio  (None, 149, 149, 32)         0         ['batch_normalization_1128[0][
#  n)                                                                 0]']
#
#  conv2d_1129 (Conv2D)        (None, 147, 147, 32)         9216      ['activation_1128[0][0]']
#
#  batch_normalization_1129 (  (None, 147, 147, 32)         96        ['conv2d_1129[0][0]']
#  BatchNormalization)
#
#  activation_1129 (Activatio  (None, 147, 147, 32)         0         ['batch_normalization_1129[0][
#  n)                                                                 0]']
#
#  conv2d_1130 (Conv2D)        (None, 147, 147, 64)         18432     ['activation_1129[0][0]']
#
#  batch_normalization_1130 (  (None, 147, 147, 64)         192       ['conv2d_1130[0][0]']
#  BatchNormalization)
#
#  activation_1130 (Activatio  (None, 147, 147, 64)         0         ['batch_normalization_1130[0][
#  n)                                                                 0]']
#
#  max_pooling2d_48 (MaxPooli  (None, 73, 73, 64)           0         ['activation_1130[0][0]']
#  ng2D)
#
#  conv2d_1131 (Conv2D)        (None, 73, 73, 80)           5120      ['max_pooling2d_48[0][0]']
#
#  batch_normalization_1131 (  (None, 73, 73, 80)           240       ['conv2d_1131[0][0]']
#  BatchNormalization)
#
#  activation_1131 (Activatio  (None, 73, 73, 80)           0         ['batch_normalization_1131[0][
#  n)                                                                 0]']
#
#  conv2d_1132 (Conv2D)        (None, 71, 71, 192)          138240    ['activation_1131[0][0]']
#
#  batch_normalization_1132 (  (None, 71, 71, 192)          576       ['conv2d_1132[0][0]']
#  BatchNormalization)
#
#  activation_1132 (Activatio  (None, 71, 71, 192)          0         ['batch_normalization_1132[0][
#  n)                                                                 0]']
#
#  max_pooling2d_49 (MaxPooli  (None, 35, 35, 192)          0         ['activation_1132[0][0]']
#  ng2D)
#
#  conv2d_1136 (Conv2D)        (None, 35, 35, 64)           12288     ['max_pooling2d_49[0][0]']
#
#  batch_normalization_1136 (  (None, 35, 35, 64)           192       ['conv2d_1136[0][0]']
#  BatchNormalization)
#
#  activation_1136 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1136[0][
#  n)                                                                 0]']
#
#  conv2d_1134 (Conv2D)        (None, 35, 35, 48)           9216      ['max_pooling2d_49[0][0]']
#
#  conv2d_1137 (Conv2D)        (None, 35, 35, 96)           55296     ['activation_1136[0][0]']
#
#  batch_normalization_1134 (  (None, 35, 35, 48)           144       ['conv2d_1134[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1137 (  (None, 35, 35, 96)           288       ['conv2d_1137[0][0]']
#  BatchNormalization)
#
#  activation_1134 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1134[0][
#  n)                                                                 0]']
#
#  activation_1137 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1137[0][
#  n)                                                                 0]']
#
#  average_pooling2d_108 (Ave  (None, 35, 35, 192)          0         ['max_pooling2d_49[0][0]']
#  ragePooling2D)
#
#  conv2d_1133 (Conv2D)        (None, 35, 35, 64)           12288     ['max_pooling2d_49[0][0]']
#
#  conv2d_1135 (Conv2D)        (None, 35, 35, 64)           76800     ['activation_1134[0][0]']
#
#  conv2d_1138 (Conv2D)        (None, 35, 35, 96)           82944     ['activation_1137[0][0]']
#
#  conv2d_1139 (Conv2D)        (None, 35, 35, 32)           6144      ['average_pooling2d_108[0][0]'
#                                                                     ]
#
#  batch_normalization_1133 (  (None, 35, 35, 64)           192       ['conv2d_1133[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1135 (  (None, 35, 35, 64)           192       ['conv2d_1135[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1138 (  (None, 35, 35, 96)           288       ['conv2d_1138[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1139 (  (None, 35, 35, 32)           96        ['conv2d_1139[0][0]']
#  BatchNormalization)
#
#  activation_1133 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1133[0][
#  n)                                                                 0]']
#
#  activation_1135 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1135[0][
#  n)                                                                 0]']
#
#  activation_1138 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1138[0][
#  n)                                                                 0]']
#
#  activation_1139 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1139[0][
#  n)                                                                 0]']
#
#  mixed0 (Concatenate)        (None, 35, 35, 256)          0         ['activation_1133[0][0]',
#                                                                      'activation_1135[0][0]',
#                                                                      'activation_1138[0][0]',
#                                                                      'activation_1139[0][0]']
#
#  conv2d_1143 (Conv2D)        (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_1143 (  (None, 35, 35, 64)           192       ['conv2d_1143[0][0]']
#  BatchNormalization)
#
#  activation_1143 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1143[0][
#  n)                                                                 0]']
#
#  conv2d_1141 (Conv2D)        (None, 35, 35, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_1144 (Conv2D)        (None, 35, 35, 96)           55296     ['activation_1143[0][0]']
#
#  batch_normalization_1141 (  (None, 35, 35, 48)           144       ['conv2d_1141[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1144 (  (None, 35, 35, 96)           288       ['conv2d_1144[0][0]']
#  BatchNormalization)
#
#  activation_1141 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1141[0][
#  n)                                                                 0]']
#
#  activation_1144 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1144[0][
#  n)                                                                 0]']
#
#  average_pooling2d_109 (Ave  (None, 35, 35, 256)          0         ['mixed0[0][0]']
#  ragePooling2D)
#
#  conv2d_1140 (Conv2D)        (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_1142 (Conv2D)        (None, 35, 35, 64)           76800     ['activation_1141[0][0]']
#
#  conv2d_1145 (Conv2D)        (None, 35, 35, 96)           82944     ['activation_1144[0][0]']
#
#  conv2d_1146 (Conv2D)        (None, 35, 35, 64)           16384     ['average_pooling2d_109[0][0]'
#                                                                     ]
#
#  batch_normalization_1140 (  (None, 35, 35, 64)           192       ['conv2d_1140[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1142 (  (None, 35, 35, 64)           192       ['conv2d_1142[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1145 (  (None, 35, 35, 96)           288       ['conv2d_1145[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1146 (  (None, 35, 35, 64)           192       ['conv2d_1146[0][0]']
#  BatchNormalization)
#
#  activation_1140 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1140[0][
#  n)                                                                 0]']
#
#  activation_1142 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1142[0][
#  n)                                                                 0]']
#
#  activation_1145 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1145[0][
#  n)                                                                 0]']
#
#  activation_1146 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1146[0][
#  n)                                                                 0]']
#
#  mixed1 (Concatenate)        (None, 35, 35, 288)          0         ['activation_1140[0][0]',
#                                                                      'activation_1142[0][0]',
#                                                                      'activation_1145[0][0]',
#                                                                      'activation_1146[0][0]']
#
#  conv2d_1150 (Conv2D)        (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_1150 (  (None, 35, 35, 64)           192       ['conv2d_1150[0][0]']
#  BatchNormalization)
#
#  activation_1150 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1150[0][
#  n)                                                                 0]']
#
#  conv2d_1148 (Conv2D)        (None, 35, 35, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_1151 (Conv2D)        (None, 35, 35, 96)           55296     ['activation_1150[0][0]']
#
#  batch_normalization_1148 (  (None, 35, 35, 48)           144       ['conv2d_1148[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1151 (  (None, 35, 35, 96)           288       ['conv2d_1151[0][0]']
#  BatchNormalization)
#
#  activation_1148 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1148[0][
#  n)                                                                 0]']
#
#  activation_1151 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1151[0][
#  n)                                                                 0]']
#
#  average_pooling2d_110 (Ave  (None, 35, 35, 288)          0         ['mixed1[0][0]']
#  ragePooling2D)
#
#  conv2d_1147 (Conv2D)        (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_1149 (Conv2D)        (None, 35, 35, 64)           76800     ['activation_1148[0][0]']
#
#  conv2d_1152 (Conv2D)        (None, 35, 35, 96)           82944     ['activation_1151[0][0]']
#
#  conv2d_1153 (Conv2D)        (None, 35, 35, 64)           18432     ['average_pooling2d_110[0][0]'
#                                                                     ]
#
#  batch_normalization_1147 (  (None, 35, 35, 64)           192       ['conv2d_1147[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1149 (  (None, 35, 35, 64)           192       ['conv2d_1149[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1152 (  (None, 35, 35, 96)           288       ['conv2d_1152[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1153 (  (None, 35, 35, 64)           192       ['conv2d_1153[0][0]']
#  BatchNormalization)
#
#  activation_1147 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1147[0][
#  n)                                                                 0]']
#
#  activation_1149 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1149[0][
#  n)                                                                 0]']
#
#  activation_1152 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1152[0][
#  n)                                                                 0]']
#
#  activation_1153 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1153[0][
#  n)                                                                 0]']
#
#  mixed2 (Concatenate)        (None, 35, 35, 288)          0         ['activation_1147[0][0]',
#                                                                      'activation_1149[0][0]',
#                                                                      'activation_1152[0][0]',
#                                                                      'activation_1153[0][0]']
#
#  conv2d_1155 (Conv2D)        (None, 35, 35, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_1155 (  (None, 35, 35, 64)           192       ['conv2d_1155[0][0]']
#  BatchNormalization)
#
#  activation_1155 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1155[0][
#  n)                                                                 0]']
#
#  conv2d_1156 (Conv2D)        (None, 35, 35, 96)           55296     ['activation_1155[0][0]']
#
#  batch_normalization_1156 (  (None, 35, 35, 96)           288       ['conv2d_1156[0][0]']
#  BatchNormalization)
#
#  activation_1156 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1156[0][
#  n)                                                                 0]']
#
#  conv2d_1154 (Conv2D)        (None, 17, 17, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_1157 (Conv2D)        (None, 17, 17, 96)           82944     ['activation_1156[0][0]']
#
#  batch_normalization_1154 (  (None, 17, 17, 384)          1152      ['conv2d_1154[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1157 (  (None, 17, 17, 96)           288       ['conv2d_1157[0][0]']
#  BatchNormalization)
#
#  activation_1154 (Activatio  (None, 17, 17, 384)          0         ['batch_normalization_1154[0][
#  n)                                                                 0]']
#
#  activation_1157 (Activatio  (None, 17, 17, 96)           0         ['batch_normalization_1157[0][
#  n)                                                                 0]']
#
#  max_pooling2d_50 (MaxPooli  (None, 17, 17, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 17, 17, 768)          0         ['activation_1154[0][0]',
#                                                                      'activation_1157[0][0]',
#                                                                      'max_pooling2d_50[0][0]']
#
#  conv2d_1162 (Conv2D)        (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_1162 (  (None, 17, 17, 128)          384       ['conv2d_1162[0][0]']
#  BatchNormalization)
#
#  activation_1162 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1162[0][
#  n)                                                                 0]']
#
#  conv2d_1163 (Conv2D)        (None, 17, 17, 128)          114688    ['activation_1162[0][0]']
#
#  batch_normalization_1163 (  (None, 17, 17, 128)          384       ['conv2d_1163[0][0]']
#  BatchNormalization)
#
#  activation_1163 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1163[0][
#  n)                                                                 0]']
#
#  conv2d_1159 (Conv2D)        (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_1164 (Conv2D)        (None, 17, 17, 128)          114688    ['activation_1163[0][0]']
#
#  batch_normalization_1159 (  (None, 17, 17, 128)          384       ['conv2d_1159[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1164 (  (None, 17, 17, 128)          384       ['conv2d_1164[0][0]']
#  BatchNormalization)
#
#  activation_1159 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1159[0][
#  n)                                                                 0]']
#
#  activation_1164 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1164[0][
#  n)                                                                 0]']
#
#  conv2d_1160 (Conv2D)        (None, 17, 17, 128)          114688    ['activation_1159[0][0]']
#
#  conv2d_1165 (Conv2D)        (None, 17, 17, 128)          114688    ['activation_1164[0][0]']
#
#  batch_normalization_1160 (  (None, 17, 17, 128)          384       ['conv2d_1160[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1165 (  (None, 17, 17, 128)          384       ['conv2d_1165[0][0]']
#  BatchNormalization)
#
#  activation_1160 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1160[0][
#  n)                                                                 0]']
#
#  activation_1165 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1165[0][
#  n)                                                                 0]']
#
#  average_pooling2d_111 (Ave  (None, 17, 17, 768)          0         ['mixed3[0][0]']
#  ragePooling2D)
#
#  conv2d_1158 (Conv2D)        (None, 17, 17, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_1161 (Conv2D)        (None, 17, 17, 192)          172032    ['activation_1160[0][0]']
#
#  conv2d_1166 (Conv2D)        (None, 17, 17, 192)          172032    ['activation_1165[0][0]']
#
#  conv2d_1167 (Conv2D)        (None, 17, 17, 192)          147456    ['average_pooling2d_111[0][0]'
#                                                                     ]
#
#  batch_normalization_1158 (  (None, 17, 17, 192)          576       ['conv2d_1158[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1161 (  (None, 17, 17, 192)          576       ['conv2d_1161[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1166 (  (None, 17, 17, 192)          576       ['conv2d_1166[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1167 (  (None, 17, 17, 192)          576       ['conv2d_1167[0][0]']
#  BatchNormalization)
#
#  activation_1158 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1158[0][
#  n)                                                                 0]']
#
#  activation_1161 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1161[0][
#  n)                                                                 0]']
#
#  activation_1166 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1166[0][
#  n)                                                                 0]']
#
#  activation_1167 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1167[0][
#  n)                                                                 0]']
#
#  mixed4 (Concatenate)        (None, 17, 17, 768)          0         ['activation_1158[0][0]',
#                                                                      'activation_1161[0][0]',
#                                                                      'activation_1166[0][0]',
#                                                                      'activation_1167[0][0]']
#
#  conv2d_1172 (Conv2D)        (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_1172 (  (None, 17, 17, 160)          480       ['conv2d_1172[0][0]']
#  BatchNormalization)
#
#  activation_1172 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1172[0][
#  n)                                                                 0]']
#
#  conv2d_1173 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1172[0][0]']
#
#  batch_normalization_1173 (  (None, 17, 17, 160)          480       ['conv2d_1173[0][0]']
#  BatchNormalization)
#
#  activation_1173 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1173[0][
#  n)                                                                 0]']
#
#  conv2d_1169 (Conv2D)        (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_1174 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1173[0][0]']
#
#  batch_normalization_1169 (  (None, 17, 17, 160)          480       ['conv2d_1169[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1174 (  (None, 17, 17, 160)          480       ['conv2d_1174[0][0]']
#  BatchNormalization)
#
#  activation_1169 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1169[0][
#  n)                                                                 0]']
#
#  activation_1174 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1174[0][
#  n)                                                                 0]']
#
#  conv2d_1170 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1169[0][0]']
#
#  conv2d_1175 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1174[0][0]']
#
#  batch_normalization_1170 (  (None, 17, 17, 160)          480       ['conv2d_1170[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1175 (  (None, 17, 17, 160)          480       ['conv2d_1175[0][0]']
#  BatchNormalization)
#
#  activation_1170 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1170[0][
#  n)                                                                 0]']
#
#  activation_1175 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1175[0][
#  n)                                                                 0]']
#
#  average_pooling2d_112 (Ave  (None, 17, 17, 768)          0         ['mixed4[0][0]']
#  ragePooling2D)
#
#  conv2d_1168 (Conv2D)        (None, 17, 17, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_1171 (Conv2D)        (None, 17, 17, 192)          215040    ['activation_1170[0][0]']
#
#  conv2d_1176 (Conv2D)        (None, 17, 17, 192)          215040    ['activation_1175[0][0]']
#
#  conv2d_1177 (Conv2D)        (None, 17, 17, 192)          147456    ['average_pooling2d_112[0][0]'
#                                                                     ]
#
#  batch_normalization_1168 (  (None, 17, 17, 192)          576       ['conv2d_1168[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1171 (  (None, 17, 17, 192)          576       ['conv2d_1171[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1176 (  (None, 17, 17, 192)          576       ['conv2d_1176[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1177 (  (None, 17, 17, 192)          576       ['conv2d_1177[0][0]']
#  BatchNormalization)
#
#  activation_1168 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1168[0][
#  n)                                                                 0]']
#
#  activation_1171 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1171[0][
#  n)                                                                 0]']
#
#  activation_1176 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1176[0][
#  n)                                                                 0]']
#
#  activation_1177 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1177[0][
#  n)                                                                 0]']
#
#  mixed5 (Concatenate)        (None, 17, 17, 768)          0         ['activation_1168[0][0]',
#                                                                      'activation_1171[0][0]',
#                                                                      'activation_1176[0][0]',
#                                                                      'activation_1177[0][0]']
#
#  conv2d_1182 (Conv2D)        (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_1182 (  (None, 17, 17, 160)          480       ['conv2d_1182[0][0]']
#  BatchNormalization)
#
#  activation_1182 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1182[0][
#  n)                                                                 0]']
#
#  conv2d_1183 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1182[0][0]']
#
#  batch_normalization_1183 (  (None, 17, 17, 160)          480       ['conv2d_1183[0][0]']
#  BatchNormalization)
#
#  activation_1183 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1183[0][
#  n)                                                                 0]']
#
#  conv2d_1179 (Conv2D)        (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_1184 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1183[0][0]']
#
#  batch_normalization_1179 (  (None, 17, 17, 160)          480       ['conv2d_1179[0][0]']
# ...
#  activation_1209 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1209[0][
#  n)                                                                 0]']
#
#  conv2d_1206 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1205[0][0]']
#
#  conv2d_1207 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1205[0][0]']
#
#  conv2d_1210 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1209[0][0]']
#
#  conv2d_1211 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1209[0][0]']
#
#  average_pooling2d_115 (Ave  (None, 8, 8, 1280)           0         ['mixed8[0][0]']
#  ragePooling2D)
#
#  conv2d_1204 (Conv2D)        (None, 8, 8, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_1206 (  (None, 8, 8, 384)            1152      ['conv2d_1206[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1207 (  (None, 8, 8, 384)            1152      ['conv2d_1207[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1210 (  (None, 8, 8, 384)            1152      ['conv2d_1210[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1211 (  (None, 8, 8, 384)            1152      ['conv2d_1211[0][0]']
#  BatchNormalization)
#
#  conv2d_1212 (Conv2D)        (None, 8, 8, 192)            245760    ['average_pooling2d_115[0][0]'
#                                                                     ]
#
#  batch_normalization_1204 (  (None, 8, 8, 320)            960       ['conv2d_1204[0][0]']
#  BatchNormalization)
#
#  activation_1206 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1206[0][
#  n)                                                                 0]']
#
#  activation_1207 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1207[0][
#  n)                                                                 0]']
#
#  activation_1210 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1210[0][
#  n)                                                                 0]']
#
#  activation_1211 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1211[0][
#  n)                                                                 0]']
#
#  batch_normalization_1212 (  (None, 8, 8, 192)            576       ['conv2d_1212[0][0]']
#  BatchNormalization)
#
#  activation_1204 (Activatio  (None, 8, 8, 320)            0         ['batch_normalization_1204[0][
#  n)                                                                 0]']
#
#  mixed9_0 (Concatenate)      (None, 8, 8, 768)            0         ['activation_1206[0][0]',
#                                                                      'activation_1207[0][0]']
#
#  concatenate_24 (Concatenat  (None, 8, 8, 768)            0         ['activation_1210[0][0]',
#  e)                                                                  'activation_1211[0][0]']
#
#  activation_1212 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1212[0][
#  n)                                                                 0]']
#
#  mixed9 (Concatenate)        (None, 8, 8, 2048)           0         ['activation_1204[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_24[0][0]',
#                                                                      'activation_1212[0][0]']
#
#  conv2d_1217 (Conv2D)        (None, 8, 8, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_1217 (  (None, 8, 8, 448)            1344      ['conv2d_1217[0][0]']
#  BatchNormalization)
#
#  activation_1217 (Activatio  (None, 8, 8, 448)            0         ['batch_normalization_1217[0][
#  n)                                                                 0]']
#
#  conv2d_1214 (Conv2D)        (None, 8, 8, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_1218 (Conv2D)        (None, 8, 8, 384)            1548288   ['activation_1217[0][0]']
#
#  batch_normalization_1214 (  (None, 8, 8, 384)            1152      ['conv2d_1214[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1218 (  (None, 8, 8, 384)            1152      ['conv2d_1218[0][0]']
#  BatchNormalization)
#
#  activation_1214 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1214[0][
#  n)                                                                 0]']
#
#  activation_1218 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1218[0][
#  n)                                                                 0]']
#
#  conv2d_1215 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1214[0][0]']
#
#  conv2d_1216 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1214[0][0]']
#
#  conv2d_1219 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1218[0][0]']
#
#  conv2d_1220 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1218[0][0]']
#
#  average_pooling2d_116 (Ave  (None, 8, 8, 2048)           0         ['mixed9[0][0]']
#  ragePooling2D)
#
#  conv2d_1213 (Conv2D)        (None, 8, 8, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_1215 (  (None, 8, 8, 384)            1152      ['conv2d_1215[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1216 (  (None, 8, 8, 384)            1152      ['conv2d_1216[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1219 (  (None, 8, 8, 384)            1152      ['conv2d_1219[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1220 (  (None, 8, 8, 384)            1152      ['conv2d_1220[0][0]']
#  BatchNormalization)
#
#  conv2d_1221 (Conv2D)        (None, 8, 8, 192)            393216    ['average_pooling2d_116[0][0]'
#                                                                     ]
#
#  batch_normalization_1213 (  (None, 8, 8, 320)            960       ['conv2d_1213[0][0]']
#  BatchNormalization)
#
#  activation_1215 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1215[0][
#  n)                                                                 0]']
#
#  activation_1216 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1216[0][
#  n)                                                                 0]']
#
#  activation_1219 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1219[0][
#  n)                                                                 0]']
#
#  activation_1220 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1220[0][
#  n)                                                                 0]']
#
#  batch_normalization_1221 (  (None, 8, 8, 192)            576       ['conv2d_1221[0][0]']
#  BatchNormalization)
#
#  activation_1213 (Activatio  (None, 8, 8, 320)            0         ['batch_normalization_1213[0][
#  n)                                                                 0]']
#
#  mixed9_1 (Concatenate)      (None, 8, 8, 768)            0         ['activation_1215[0][0]',
#                                                                      'activation_1216[0][0]']
#
#  concatenate_25 (Concatenat  (None, 8, 8, 768)            0         ['activation_1219[0][0]',
#  e)                                                                  'activation_1220[0][0]']
#
#  activation_1221 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1221[0][
#  n)                                                                 0]']
#
#  mixed10 (Concatenate)       (None, 8, 8, 2048)           0         ['activation_1213[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_25[0][0]',
#                                                                      'activation_1221[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['mixed10[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 2049000   ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23851784 (90.99 MB)
# Trainable params: 23817352 (90.86 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# - include_top= True : will keep the output layer.
# - include_top=False: will keep all the laeyrs except last layer

# %%
x = tf.random.normal(shape=(3, 299, 299, 3))
y = tf.constant([0, 1, 2])

# %%
base_inputs = model.layers[0].input
base_outputs = model.layers[-2].output
classifier = layers.Dense(3)(base_outputs)
new_model = keras.Model(inputs=base_inputs, outputs=classifier)

# %%
new_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"],
)

# %%
print(new_model.summary())
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 299, 299, 3)]        0         []
#
#  conv2d_1128 (Conv2D)        (None, 149, 149, 32)         864       ['input_13[0][0]']
#
#  batch_normalization_1128 (  (None, 149, 149, 32)         96        ['conv2d_1128[0][0]']
#  BatchNormalization)
#
#  activation_1128 (Activatio  (None, 149, 149, 32)         0         ['batch_normalization_1128[0][
#  n)                                                                 0]']
#
#  conv2d_1129 (Conv2D)        (None, 147, 147, 32)         9216      ['activation_1128[0][0]']
#
#  batch_normalization_1129 (  (None, 147, 147, 32)         96        ['conv2d_1129[0][0]']
#  BatchNormalization)
#
#  activation_1129 (Activatio  (None, 147, 147, 32)         0         ['batch_normalization_1129[0][
#  n)                                                                 0]']
#
#  conv2d_1130 (Conv2D)        (None, 147, 147, 64)         18432     ['activation_1129[0][0]']
#
#  batch_normalization_1130 (  (None, 147, 147, 64)         192       ['conv2d_1130[0][0]']
#  BatchNormalization)
#
#  activation_1130 (Activatio  (None, 147, 147, 64)         0         ['batch_normalization_1130[0][
#  n)                                                                 0]']
#
#  max_pooling2d_48 (MaxPooli  (None, 73, 73, 64)           0         ['activation_1130[0][0]']
#  ng2D)
#
#  conv2d_1131 (Conv2D)        (None, 73, 73, 80)           5120      ['max_pooling2d_48[0][0]']
#
#  batch_normalization_1131 (  (None, 73, 73, 80)           240       ['conv2d_1131[0][0]']
#  BatchNormalization)
#
#  activation_1131 (Activatio  (None, 73, 73, 80)           0         ['batch_normalization_1131[0][
#  n)                                                                 0]']
#
#  conv2d_1132 (Conv2D)        (None, 71, 71, 192)          138240    ['activation_1131[0][0]']
#
#  batch_normalization_1132 (  (None, 71, 71, 192)          576       ['conv2d_1132[0][0]']
#  BatchNormalization)
#
#  activation_1132 (Activatio  (None, 71, 71, 192)          0         ['batch_normalization_1132[0][
#  n)                                                                 0]']
#
#  max_pooling2d_49 (MaxPooli  (None, 35, 35, 192)          0         ['activation_1132[0][0]']
#  ng2D)
#
#  conv2d_1136 (Conv2D)        (None, 35, 35, 64)           12288     ['max_pooling2d_49[0][0]']
#
#  batch_normalization_1136 (  (None, 35, 35, 64)           192       ['conv2d_1136[0][0]']
#  BatchNormalization)
#
#  activation_1136 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1136[0][
#  n)                                                                 0]']
#
#  conv2d_1134 (Conv2D)        (None, 35, 35, 48)           9216      ['max_pooling2d_49[0][0]']
#
#  conv2d_1137 (Conv2D)        (None, 35, 35, 96)           55296     ['activation_1136[0][0]']
#
#  batch_normalization_1134 (  (None, 35, 35, 48)           144       ['conv2d_1134[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1137 (  (None, 35, 35, 96)           288       ['conv2d_1137[0][0]']
#  BatchNormalization)
#
#  activation_1134 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1134[0][
#  n)                                                                 0]']
#
#  activation_1137 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1137[0][
#  n)                                                                 0]']
#
#  average_pooling2d_108 (Ave  (None, 35, 35, 192)          0         ['max_pooling2d_49[0][0]']
#  ragePooling2D)
#
#  conv2d_1133 (Conv2D)        (None, 35, 35, 64)           12288     ['max_pooling2d_49[0][0]']
#
#  conv2d_1135 (Conv2D)        (None, 35, 35, 64)           76800     ['activation_1134[0][0]']
#
#  conv2d_1138 (Conv2D)        (None, 35, 35, 96)           82944     ['activation_1137[0][0]']
#
#  conv2d_1139 (Conv2D)        (None, 35, 35, 32)           6144      ['average_pooling2d_108[0][0]'
#                                                                     ]
#
#  batch_normalization_1133 (  (None, 35, 35, 64)           192       ['conv2d_1133[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1135 (  (None, 35, 35, 64)           192       ['conv2d_1135[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1138 (  (None, 35, 35, 96)           288       ['conv2d_1138[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1139 (  (None, 35, 35, 32)           96        ['conv2d_1139[0][0]']
#  BatchNormalization)
#
#  activation_1133 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1133[0][
#  n)                                                                 0]']
#
#  activation_1135 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1135[0][
#  n)                                                                 0]']
#
#  activation_1138 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1138[0][
#  n)                                                                 0]']
#
#  activation_1139 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1139[0][
#  n)                                                                 0]']
#
#  mixed0 (Concatenate)        (None, 35, 35, 256)          0         ['activation_1133[0][0]',
#                                                                      'activation_1135[0][0]',
#                                                                      'activation_1138[0][0]',
#                                                                      'activation_1139[0][0]']
#
#  conv2d_1143 (Conv2D)        (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_1143 (  (None, 35, 35, 64)           192       ['conv2d_1143[0][0]']
#  BatchNormalization)
#
#  activation_1143 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1143[0][
#  n)                                                                 0]']
#
#  conv2d_1141 (Conv2D)        (None, 35, 35, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_1144 (Conv2D)        (None, 35, 35, 96)           55296     ['activation_1143[0][0]']
#
#  batch_normalization_1141 (  (None, 35, 35, 48)           144       ['conv2d_1141[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1144 (  (None, 35, 35, 96)           288       ['conv2d_1144[0][0]']
#  BatchNormalization)
#
#  activation_1141 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1141[0][
#  n)                                                                 0]']
#
#  activation_1144 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1144[0][
#  n)                                                                 0]']
#
#  average_pooling2d_109 (Ave  (None, 35, 35, 256)          0         ['mixed0[0][0]']
#  ragePooling2D)
#
#  conv2d_1140 (Conv2D)        (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_1142 (Conv2D)        (None, 35, 35, 64)           76800     ['activation_1141[0][0]']
#
#  conv2d_1145 (Conv2D)        (None, 35, 35, 96)           82944     ['activation_1144[0][0]']
#
#  conv2d_1146 (Conv2D)        (None, 35, 35, 64)           16384     ['average_pooling2d_109[0][0]'
#                                                                     ]
#
#  batch_normalization_1140 (  (None, 35, 35, 64)           192       ['conv2d_1140[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1142 (  (None, 35, 35, 64)           192       ['conv2d_1142[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1145 (  (None, 35, 35, 96)           288       ['conv2d_1145[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1146 (  (None, 35, 35, 64)           192       ['conv2d_1146[0][0]']
#  BatchNormalization)
#
#  activation_1140 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1140[0][
#  n)                                                                 0]']
#
#  activation_1142 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1142[0][
#  n)                                                                 0]']
#
#  activation_1145 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1145[0][
#  n)                                                                 0]']
#
#  activation_1146 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1146[0][
#  n)                                                                 0]']
#
#  mixed1 (Concatenate)        (None, 35, 35, 288)          0         ['activation_1140[0][0]',
#                                                                      'activation_1142[0][0]',
#                                                                      'activation_1145[0][0]',
#                                                                      'activation_1146[0][0]']
#
#  conv2d_1150 (Conv2D)        (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_1150 (  (None, 35, 35, 64)           192       ['conv2d_1150[0][0]']
#  BatchNormalization)
#
#  activation_1150 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1150[0][
#  n)                                                                 0]']
#
#  conv2d_1148 (Conv2D)        (None, 35, 35, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_1151 (Conv2D)        (None, 35, 35, 96)           55296     ['activation_1150[0][0]']
#
#  batch_normalization_1148 (  (None, 35, 35, 48)           144       ['conv2d_1148[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1151 (  (None, 35, 35, 96)           288       ['conv2d_1151[0][0]']
#  BatchNormalization)
#
#  activation_1148 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1148[0][
#  n)                                                                 0]']
#
#  activation_1151 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1151[0][
#  n)                                                                 0]']
#
#  average_pooling2d_110 (Ave  (None, 35, 35, 288)          0         ['mixed1[0][0]']
#  ragePooling2D)
#
#  conv2d_1147 (Conv2D)        (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_1149 (Conv2D)        (None, 35, 35, 64)           76800     ['activation_1148[0][0]']
#
#  conv2d_1152 (Conv2D)        (None, 35, 35, 96)           82944     ['activation_1151[0][0]']
#
#  conv2d_1153 (Conv2D)        (None, 35, 35, 64)           18432     ['average_pooling2d_110[0][0]'
#                                                                     ]
#
#  batch_normalization_1147 (  (None, 35, 35, 64)           192       ['conv2d_1147[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1149 (  (None, 35, 35, 64)           192       ['conv2d_1149[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1152 (  (None, 35, 35, 96)           288       ['conv2d_1152[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1153 (  (None, 35, 35, 64)           192       ['conv2d_1153[0][0]']
#  BatchNormalization)
#
#  activation_1147 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1147[0][
#  n)                                                                 0]']
#
#  activation_1149 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1149[0][
#  n)                                                                 0]']
#
#  activation_1152 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1152[0][
#  n)                                                                 0]']
#
#  activation_1153 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1153[0][
#  n)                                                                 0]']
#
#  mixed2 (Concatenate)        (None, 35, 35, 288)          0         ['activation_1147[0][0]',
#                                                                      'activation_1149[0][0]',
#                                                                      'activation_1152[0][0]',
#                                                                      'activation_1153[0][0]']
#
#  conv2d_1155 (Conv2D)        (None, 35, 35, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_1155 (  (None, 35, 35, 64)           192       ['conv2d_1155[0][0]']
#  BatchNormalization)
#
#  activation_1155 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1155[0][
#  n)                                                                 0]']
#
#  conv2d_1156 (Conv2D)        (None, 35, 35, 96)           55296     ['activation_1155[0][0]']
#
#  batch_normalization_1156 (  (None, 35, 35, 96)           288       ['conv2d_1156[0][0]']
#  BatchNormalization)
#
#  activation_1156 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1156[0][
#  n)                                                                 0]']
#
#  conv2d_1154 (Conv2D)        (None, 17, 17, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_1157 (Conv2D)        (None, 17, 17, 96)           82944     ['activation_1156[0][0]']
#
#  batch_normalization_1154 (  (None, 17, 17, 384)          1152      ['conv2d_1154[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1157 (  (None, 17, 17, 96)           288       ['conv2d_1157[0][0]']
#  BatchNormalization)
#
#  activation_1154 (Activatio  (None, 17, 17, 384)          0         ['batch_normalization_1154[0][
#  n)                                                                 0]']
#
#  activation_1157 (Activatio  (None, 17, 17, 96)           0         ['batch_normalization_1157[0][
#  n)                                                                 0]']
#
#  max_pooling2d_50 (MaxPooli  (None, 17, 17, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 17, 17, 768)          0         ['activation_1154[0][0]',
#                                                                      'activation_1157[0][0]',
#                                                                      'max_pooling2d_50[0][0]']
#
#  conv2d_1162 (Conv2D)        (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_1162 (  (None, 17, 17, 128)          384       ['conv2d_1162[0][0]']
#  BatchNormalization)
#
#  activation_1162 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1162[0][
#  n)                                                                 0]']
#
#  conv2d_1163 (Conv2D)        (None, 17, 17, 128)          114688    ['activation_1162[0][0]']
#
#  batch_normalization_1163 (  (None, 17, 17, 128)          384       ['conv2d_1163[0][0]']
#  BatchNormalization)
#
#  activation_1163 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1163[0][
#  n)                                                                 0]']
#
#  conv2d_1159 (Conv2D)        (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_1164 (Conv2D)        (None, 17, 17, 128)          114688    ['activation_1163[0][0]']
#
#  batch_normalization_1159 (  (None, 17, 17, 128)          384       ['conv2d_1159[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1164 (  (None, 17, 17, 128)          384       ['conv2d_1164[0][0]']
#  BatchNormalization)
#
#  activation_1159 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1159[0][
#  n)                                                                 0]']
#
#  activation_1164 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1164[0][
#  n)                                                                 0]']
#
#  conv2d_1160 (Conv2D)        (None, 17, 17, 128)          114688    ['activation_1159[0][0]']
#
#  conv2d_1165 (Conv2D)        (None, 17, 17, 128)          114688    ['activation_1164[0][0]']
#
#  batch_normalization_1160 (  (None, 17, 17, 128)          384       ['conv2d_1160[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1165 (  (None, 17, 17, 128)          384       ['conv2d_1165[0][0]']
#  BatchNormalization)
#
#  activation_1160 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1160[0][
#  n)                                                                 0]']
#
#  activation_1165 (Activatio  (None, 17, 17, 128)          0         ['batch_normalization_1165[0][
#  n)                                                                 0]']
#
#  average_pooling2d_111 (Ave  (None, 17, 17, 768)          0         ['mixed3[0][0]']
#  ragePooling2D)
#
#  conv2d_1158 (Conv2D)        (None, 17, 17, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_1161 (Conv2D)        (None, 17, 17, 192)          172032    ['activation_1160[0][0]']
#
#  conv2d_1166 (Conv2D)        (None, 17, 17, 192)          172032    ['activation_1165[0][0]']
#
#  conv2d_1167 (Conv2D)        (None, 17, 17, 192)          147456    ['average_pooling2d_111[0][0]'
#                                                                     ]
#
#  batch_normalization_1158 (  (None, 17, 17, 192)          576       ['conv2d_1158[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1161 (  (None, 17, 17, 192)          576       ['conv2d_1161[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1166 (  (None, 17, 17, 192)          576       ['conv2d_1166[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1167 (  (None, 17, 17, 192)          576       ['conv2d_1167[0][0]']
#  BatchNormalization)
#
#  activation_1158 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1158[0][
#  n)                                                                 0]']
#
#  activation_1161 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1161[0][
#  n)                                                                 0]']
#
#  activation_1166 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1166[0][
#  n)                                                                 0]']
#
#  activation_1167 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1167[0][
#  n)                                                                 0]']
#
#  mixed4 (Concatenate)        (None, 17, 17, 768)          0         ['activation_1158[0][0]',
#                                                                      'activation_1161[0][0]',
#                                                                      'activation_1166[0][0]',
#                                                                      'activation_1167[0][0]']
#
#  conv2d_1172 (Conv2D)        (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_1172 (  (None, 17, 17, 160)          480       ['conv2d_1172[0][0]']
#  BatchNormalization)
#
#  activation_1172 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1172[0][
#  n)                                                                 0]']
#
#  conv2d_1173 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1172[0][0]']
#
#  batch_normalization_1173 (  (None, 17, 17, 160)          480       ['conv2d_1173[0][0]']
#  BatchNormalization)
#
#  activation_1173 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1173[0][
#  n)                                                                 0]']
#
#  conv2d_1169 (Conv2D)        (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_1174 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1173[0][0]']
#
#  batch_normalization_1169 (  (None, 17, 17, 160)          480       ['conv2d_1169[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1174 (  (None, 17, 17, 160)          480       ['conv2d_1174[0][0]']
#  BatchNormalization)
#
#  activation_1169 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1169[0][
#  n)                                                                 0]']
#
#  activation_1174 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1174[0][
#  n)                                                                 0]']
#
#  conv2d_1170 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1169[0][0]']
#
#  conv2d_1175 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1174[0][0]']
#
#  batch_normalization_1170 (  (None, 17, 17, 160)          480       ['conv2d_1170[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1175 (  (None, 17, 17, 160)          480       ['conv2d_1175[0][0]']
#  BatchNormalization)
#
#  activation_1170 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1170[0][
#  n)                                                                 0]']
#
#  activation_1175 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1175[0][
#  n)                                                                 0]']
#
#  average_pooling2d_112 (Ave  (None, 17, 17, 768)          0         ['mixed4[0][0]']
#  ragePooling2D)
#
#  conv2d_1168 (Conv2D)        (None, 17, 17, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_1171 (Conv2D)        (None, 17, 17, 192)          215040    ['activation_1170[0][0]']
#
#  conv2d_1176 (Conv2D)        (None, 17, 17, 192)          215040    ['activation_1175[0][0]']
#
#  conv2d_1177 (Conv2D)        (None, 17, 17, 192)          147456    ['average_pooling2d_112[0][0]'
#                                                                     ]
#
#  batch_normalization_1168 (  (None, 17, 17, 192)          576       ['conv2d_1168[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1171 (  (None, 17, 17, 192)          576       ['conv2d_1171[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1176 (  (None, 17, 17, 192)          576       ['conv2d_1176[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1177 (  (None, 17, 17, 192)          576       ['conv2d_1177[0][0]']
#  BatchNormalization)
#
#  activation_1168 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1168[0][
#  n)                                                                 0]']
#
#  activation_1171 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1171[0][
#  n)                                                                 0]']
#
#  activation_1176 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1176[0][
#  n)                                                                 0]']
#
#  activation_1177 (Activatio  (None, 17, 17, 192)          0         ['batch_normalization_1177[0][
#  n)                                                                 0]']
#
#  mixed5 (Concatenate)        (None, 17, 17, 768)          0         ['activation_1168[0][0]',
#                                                                      'activation_1171[0][0]',
#                                                                      'activation_1176[0][0]',
#                                                                      'activation_1177[0][0]']
#
#  conv2d_1182 (Conv2D)        (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_1182 (  (None, 17, 17, 160)          480       ['conv2d_1182[0][0]']
#  BatchNormalization)
#
#  activation_1182 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1182[0][
#  n)                                                                 0]']
#
#  conv2d_1183 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1182[0][0]']
#
#  batch_normalization_1183 (  (None, 17, 17, 160)          480       ['conv2d_1183[0][0]']
#  BatchNormalization)
#
#  activation_1183 (Activatio  (None, 17, 17, 160)          0         ['batch_normalization_1183[0][
#  n)                                                                 0]']
#
#  conv2d_1179 (Conv2D)        (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_1184 (Conv2D)        (None, 17, 17, 160)          179200    ['activation_1183[0][0]']
#
#  batch_normalization_1179 (  (None, 17, 17, 160)          480       ['conv2d_1179[0][0]']
# ...
#  activation_1209 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1209[0][
#  n)                                                                 0]']
#
#  conv2d_1206 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1205[0][0]']
#
#  conv2d_1207 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1205[0][0]']
#
#  conv2d_1210 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1209[0][0]']
#
#  conv2d_1211 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1209[0][0]']
#
#  average_pooling2d_115 (Ave  (None, 8, 8, 1280)           0         ['mixed8[0][0]']
#  ragePooling2D)
#
#  conv2d_1204 (Conv2D)        (None, 8, 8, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_1206 (  (None, 8, 8, 384)            1152      ['conv2d_1206[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1207 (  (None, 8, 8, 384)            1152      ['conv2d_1207[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1210 (  (None, 8, 8, 384)            1152      ['conv2d_1210[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1211 (  (None, 8, 8, 384)            1152      ['conv2d_1211[0][0]']
#  BatchNormalization)
#
#  conv2d_1212 (Conv2D)        (None, 8, 8, 192)            245760    ['average_pooling2d_115[0][0]'
#                                                                     ]
#
#  batch_normalization_1204 (  (None, 8, 8, 320)            960       ['conv2d_1204[0][0]']
#  BatchNormalization)
#
#  activation_1206 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1206[0][
#  n)                                                                 0]']
#
#  activation_1207 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1207[0][
#  n)                                                                 0]']
#
#  activation_1210 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1210[0][
#  n)                                                                 0]']
#
#  activation_1211 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1211[0][
#  n)                                                                 0]']
#
#  batch_normalization_1212 (  (None, 8, 8, 192)            576       ['conv2d_1212[0][0]']
#  BatchNormalization)
#
#  activation_1204 (Activatio  (None, 8, 8, 320)            0         ['batch_normalization_1204[0][
#  n)                                                                 0]']
#
#  mixed9_0 (Concatenate)      (None, 8, 8, 768)            0         ['activation_1206[0][0]',
#                                                                      'activation_1207[0][0]']
#
#  concatenate_24 (Concatenat  (None, 8, 8, 768)            0         ['activation_1210[0][0]',
#  e)                                                                  'activation_1211[0][0]']
#
#  activation_1212 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1212[0][
#  n)                                                                 0]']
#
#  mixed9 (Concatenate)        (None, 8, 8, 2048)           0         ['activation_1204[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_24[0][0]',
#                                                                      'activation_1212[0][0]']
#
#  conv2d_1217 (Conv2D)        (None, 8, 8, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_1217 (  (None, 8, 8, 448)            1344      ['conv2d_1217[0][0]']
#  BatchNormalization)
#
#  activation_1217 (Activatio  (None, 8, 8, 448)            0         ['batch_normalization_1217[0][
#  n)                                                                 0]']
#
#  conv2d_1214 (Conv2D)        (None, 8, 8, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_1218 (Conv2D)        (None, 8, 8, 384)            1548288   ['activation_1217[0][0]']
#
#  batch_normalization_1214 (  (None, 8, 8, 384)            1152      ['conv2d_1214[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1218 (  (None, 8, 8, 384)            1152      ['conv2d_1218[0][0]']
#  BatchNormalization)
#
#  activation_1214 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1214[0][
#  n)                                                                 0]']
#
#  activation_1218 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1218[0][
#  n)                                                                 0]']
#
#  conv2d_1215 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1214[0][0]']
#
#  conv2d_1216 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1214[0][0]']
#
#  conv2d_1219 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1218[0][0]']
#
#  conv2d_1220 (Conv2D)        (None, 8, 8, 384)            442368    ['activation_1218[0][0]']
#
#  average_pooling2d_116 (Ave  (None, 8, 8, 2048)           0         ['mixed9[0][0]']
#  ragePooling2D)
#
#  conv2d_1213 (Conv2D)        (None, 8, 8, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_1215 (  (None, 8, 8, 384)            1152      ['conv2d_1215[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1216 (  (None, 8, 8, 384)            1152      ['conv2d_1216[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1219 (  (None, 8, 8, 384)            1152      ['conv2d_1219[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1220 (  (None, 8, 8, 384)            1152      ['conv2d_1220[0][0]']
#  BatchNormalization)
#
#  conv2d_1221 (Conv2D)        (None, 8, 8, 192)            393216    ['average_pooling2d_116[0][0]'
#                                                                     ]
#
#  batch_normalization_1213 (  (None, 8, 8, 320)            960       ['conv2d_1213[0][0]']
#  BatchNormalization)
#
#  activation_1215 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1215[0][
#  n)                                                                 0]']
#
#  activation_1216 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1216[0][
#  n)                                                                 0]']
#
#  activation_1219 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1219[0][
#  n)                                                                 0]']
#
#  activation_1220 (Activatio  (None, 8, 8, 384)            0         ['batch_normalization_1220[0][
#  n)                                                                 0]']
#
#  batch_normalization_1221 (  (None, 8, 8, 192)            576       ['conv2d_1221[0][0]']
#  BatchNormalization)
#
#  activation_1213 (Activatio  (None, 8, 8, 320)            0         ['batch_normalization_1213[0][
#  n)                                                                 0]']
#
#  mixed9_1 (Concatenate)      (None, 8, 8, 768)            0         ['activation_1215[0][0]',
#                                                                      'activation_1216[0][0]']
#
#  concatenate_25 (Concatenat  (None, 8, 8, 768)            0         ['activation_1219[0][0]',
#  e)                                                                  'activation_1220[0][0]']
#
#  activation_1221 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1221[0][
#  n)                                                                 0]']
#
#  mixed10 (Concatenate)       (None, 8, 8, 2048)           0         ['activation_1213[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_25[0][0]',
#                                                                      'activation_1221[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['mixed10[0][0]']
#  ling2D)
#
#  dense_12 (Dense)            (None, 3)                    6147      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 21808931 (83.19 MB)
# Trainable params: 21774499 (83.06 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________
# None

# %%
new_model.fit(x, y, epochs=15, verbose=2)
# Out:
# Epoch 1/15
# 1/1 - 20s - loss: 1.4221 - accuracy: 0.3333 - 20s/epoch - 20s/step
# Epoch 2/15
# 1/1 - 2s - loss: 0.0661 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 3/15
# 1/1 - 2s - loss: 5.6145e-05 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 4/15
# 1/1 - 2s - loss: 1.1444e-05 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 5/15
# 1/1 - 2s - loss: 5.2849e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 6/15
# 1/1 - 2s - loss: 3.3378e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 7/15
# 1/1 - 2s - loss: 2.3842e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 8/15
# 1/1 - 2s - loss: 1.8676e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 9/15
# 1/1 - 2s - loss: 1.6292e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 10/15
# 1/1 - 2s - loss: 1.4702e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 11/15
# 1/1 - 2s - loss: 1.3908e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 12/15
# 1/1 - 2s - loss: 1.2318e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 13/15
# 1/1 - 2s - loss: 1.1921e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 14/15
# 1/1 - 2s - loss: 1.1524e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
# Epoch 15/15
# 1/1 - 2s - loss: 1.1126e-06 - accuracy: 1.0000 - 2s/epoch - 2s/step
